# %% [markdown]
# # AgroENSO Risk IA
# Análise exploratória da base da POC.

# %%
import pandas as pd
df = pd.read_csv('../data/base_agroenso_risk_goias.csv')
df.head()

# %%
df.groupby(['municipio','cultura'])['irea_indice_risco_enso_agricola'].mean().sort_values(ascending=False).head(10)
